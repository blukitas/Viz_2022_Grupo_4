# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sqlalchemy import create_engine

# %%
POSTGRES_USER = "viz_user"
POSTGRES_PASSWORD = "viz_pass"
POSTGRES_DB = "viz"

# %%
engine = create_engine(
    f"postgresql+psycopg2://{POSTGRES_USER}:{POSTGRES_PASSWORD}@localhost/{POSTGRES_DB}"
)

# %%
SQL = """select 
	"month", 
	educationlevel, -- Podemos cambiar el nivel de agrupamiento
	ROUND(avg(wage_amt)::numeric, 2) as avg_wage_amt, 
	ROUND(avg(food_amt)::numeric, 2) as avg_food_amt, 
	ROUND(avg(education_amt)::numeric, 2) as avg_education_amt, 
	ROUND(avg(shelter_amt)::numeric, 2) as avg_shelter_amt
from 
	vo_monthly_wage_cohorts vmwc 
group by 1,2
order by 1,4
"""

# %%
df = pd.read_sql(SQL, engine)

# %%
df.head(5)
# Out:
#      month       educationlevel  avg_wage_amt  avg_food_amt  \
# 0  2022-03             Graduate       9802.94       -376.68
# 1  2022-03            Bachelors       7902.45       -364.70
# 2  2022-03  HighSchoolOrCollege       4895.11       -301.01
# 3  2022-03                  Low       3963.30       -251.99
# 4  2022-04             Graduate       5796.96       -358.17
#
#    avg_education_amt  avg_shelter_amt
# 0             -26.25         -1434.50
# 1             -20.50         -1421.68
# 2             -30.76         -1000.56
# 3             -39.77          -757.84
# 4             -13.12          -687.83

# %%
df.dtypes
# Out:
# month                 object
# educationlevel        object
# avg_wage_amt         float64
# avg_food_amt         float64
# avg_education_amt    float64
# avg_shelter_amt      float64
# dtype: object

# %%
df.shape
# Out:
# (60, 6)

# %%
df.educationlevel.value_counts()
# Out:
# Graduate               15
# Bachelors              15
# HighSchoolOrCollege    15
# Low                    15
# Name: educationlevel, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %% [markdown]
# ## Plot avg from each participant

# %%
SQL = """select * from vo_monthly_wage;"""

# %%
df = pd.read_sql(SQL, engine)

# %%
df.head(5)
# Out:
#      month  participantid  wage_amt  food_amt  education_amt  shelter_amt  \
# 0  2022-03              0  11931.95   -268.34         -76.01     -1109.98
# 1  2022-03              1  10359.02   -288.94         -76.01     -1109.98
# 2  2022-03              2   9722.06   -290.48         -25.62     -1113.11
# 3  2022-03              3   9407.86   -291.98         -76.01     -1109.98
# 4  2022-03              4  11589.79   -300.05         -25.62     -7385.95
#
#    earning_amt  spend_amt  balance_amt
# 0     11931.95   -1454.33     11014.30
# 1     10359.02   -1474.93      9461.98
# 2      9722.06   -1429.21      8873.82
# 3      9407.86   -1477.97      8513.85
# 4     11589.79   -7711.62      4478.26

# %%
df.dtypes
# Out:
# month             object
# participantid      int64
# wage_amt         float64
# food_amt         float64
# education_amt    float64
# shelter_amt      float64
# earning_amt      float64
# spend_amt        float64
# balance_amt      float64
# dtype: object

# %%
df.shape
# Out:
# (13331, 9)

# %%
# Big bins
plt.hist2d(
    df["food_amt"],
    np.array(df["wage_amt"], dtype=float),
    bins=(50, 50),
    cmap=plt.cm.jet,
)
plt.show()

# %%
# Big bins
plt.hist2d(
    df["participantid"],
    np.array(df["wage_amt"], dtype=float),
    bins=(50, 50),
    cmap=plt.cm.jet,
)
plt.show()

# %% [markdown]
# ## Plot wages from each participant

# %%
SQL = """select * from financialjournal;"""

# %%
df = pd.read_sql(SQL, engine)

# %%
df.head(5)
# Out:
#    participantid             timestamp   category       amount
# 0              0  2022-03-01T00:00:00Z       Wage  2472.507559
# 1              0  2022-03-01T00:00:00Z    Shelter  -554.988622
# 2              0  2022-03-01T00:00:00Z  Education   -38.005380
# 3              1  2022-03-01T00:00:00Z       Wage  2046.562206
# 4              1  2022-03-01T00:00:00Z    Shelter  -554.988622

# %%
df.dtypes
# Out:
# participantid      int64
# timestamp         object
# category          object
# amount           float64
# dtype: object

# %%
df.shape
# Out:
# (1856330, 4)

# %%
df[df.category == "Wage"].shape
# Out:
# (508577, 4)

# %%
df[df.category == "Shelter"].shape
# Out:
# (14103, 4)

# %%
# # No da hay menos registros de cada uno
# # Big bins
# plt.hist2d(df[df.category == "Shelter"]["amount"], df[df.category == "Wage"]["amount"], bins=(50, 50), cmap=plt.cm.jet)
# plt.show()

# %%
# Big bins
figure(figsize=(13, 6), dpi=40)

plt.hist2d(
    df[df.category == "Wage"]["participantid"],
    df[df.category == "Wage"]["amount"],
    bins=(200, 200),
    cmap=plt.cm.jet,
)
plt.show()

# %% [markdown]
# # financial journal

# %%
SQL = """select * from vo_monthly_wage"""
df = pd.read_sql(SQL, engine)

# %%
df.spend_amt = -1 * df.spend_amt

# %%
fig, ax = plt.subplots(figsize=(12,5))

for participant in df.participantid.tolist():
    ax.plot(
        "month",
        "earning_amt",
        data=df[df.participantid == participant],
        marker=".",
        markerfacecolor="green",
        markersize=1,
        color="lightgreen",
        alpha=0.1,
        linewidth=1,
    )
    ax.plot(
        "month",
        "spend_amt",
        data=df[df.participantid == participant],
        marker=".",
        markerfacecolor="red",
        markersize=1,
        color="red",
        alpha=0.1,
        linewidth=1,
    )
# ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,5))

for participant in df.participantid.tolist():
    ax.plot(
        "month",
        "spend_amt",
        data=df[df.participantid == participant],
        marker=".",
        markerfacecolor="red",
        markersize=1,
        color="red",
        alpha=0.1,
        linewidth=1,
    )
# ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %% [markdown]
# ## Daily wage

# %%
SQL = """
  select vdw.* 
  	from vo_daily_wage vdw
  	left join vo_date vd on vd.dt = vdw."month" 
  	where vd.dt_day_of_week = 1
"""
df = pd.read_sql(SQL, engine)

# %%
df.spend_amt = -1 * df.spend_amt

# %%
fig, ax = plt.subplots(figsize=(30,10))

for participant in df.participantid.tolist():
    ax.plot(
        "month",
        "earning_amt",
        data=df[df.participantid == participant],
        color="lightgreen",
        alpha=0.1,
        linewidth=1,
    )
    ax.plot(
        "month",
        "spend_amt",
        data=df[df.participantid == participant],
        color="red",
        alpha=0.1,
        linewidth=1,
    )
# ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))

for participant in df.participantid.tolist():
    ax.plot(
        "month",
        "spend_amt",
        data=df[df.participantid == participant],
        # marker=".",
        # markerfacecolor="red",
        # markersize=1,
        color="red",
        alpha=0.1,
        linewidth=1,
    )

plt.show()

# %%
df.head()
# Out:
#         month  participantid  wage_amt  food_amt  education_amt  shelter_amt  \
# 0  2022-03-21              0    411.28     -8.17            0.0          0.0
# 1  2022-03-21              1    361.41    -11.49            0.0          0.0
# 2  2022-03-21              2    316.75     -8.00            0.0          0.0
# 3  2022-03-21              3    306.14     -9.11            0.0          0.0
# 4  2022-03-21              4    396.91     -8.07            0.0          0.0
#
#    earning_amt  spend_amt  balance_amt
# 0       411.28       8.17       419.45
# 1       361.41      11.49       372.90
# 2       316.75       8.00       324.75
# 3       306.14       9.11       315.25
# 4       396.91       8.07       404.98

# %%
df[df.month=='2022-03-07'].hist()
# Out:
# array([[<AxesSubplot:title={'center':'participantid'}>,
#         <AxesSubplot:title={'center':'wage_amt'}>,
#         <AxesSubplot:title={'center':'food_amt'}>],
#        [<AxesSubplot:title={'center':'education_amt'}>,
#         <AxesSubplot:title={'center':'shelter_amt'}>,
#         <AxesSubplot:title={'center':'earning_amt'}>],
#        [<AxesSubplot:title={'center':'spend_amt'}>,
#         <AxesSubplot:title={'center':'balance_amt'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df[df.month=='2022-03-07'].wage_amt.hist()
# Out:
# <AxesSubplot:>

# %%
df[df.month=='2022-04-04'].wage_amt.hist()
# Out:
# <AxesSubplot:>

# %%
df[df.month=='2022-03-07'].spend_amt.hist()
# Out:
# <AxesSubplot:>

# %%
# df[df.month=='2022-04-04'].spend_amt.hist()

figure(figsize=(30, 10), dpi=80)
plt.figure(figsize=(30,10))



n,bins,patch = plt.hist(df[df.month=='2022-04-04'].spend_amt,bins=100, color='green', alpha=0.8, label='Value', edgecolor='orange', linewidth=2)
plt.legend()
# plt.ylabel('No of bags', size='x-large')
# plt.xlabel('Money in US $', size= 'x-large')
# Out:
# <AxesSubplot:>

# %%
df[df.month=='2022-04-11'].spend_amt.hist()
# Out:
# <AxesSubplot:>

# %%
df[df.month=='2022-04-11'].hist()
# Out:
# array([[<AxesSubplot:title={'center':'participantid'}>,
#         <AxesSubplot:title={'center':'wage_amt'}>,
#         <AxesSubplot:title={'center':'food_amt'}>],
#        [<AxesSubplot:title={'center':'education_amt'}>,
#         <AxesSubplot:title={'center':'shelter_amt'}>,
#         <AxesSubplot:title={'center':'earning_amt'}>],
#        [<AxesSubplot:title={'center':'spend_amt'}>,
#         <AxesSubplot:title={'center':'balance_amt'}>, <AxesSubplot:>]],
#       dtype=object)
