# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sqlalchemy import create_engine

# %%
POSTGRES_USER = "viz_user"
POSTGRES_PASSWORD = "viz_pass"
POSTGRES_DB = "viz"

# %%
engine = create_engine(
    f"postgresql+psycopg2://{POSTGRES_USER}:{POSTGRES_PASSWORD}@localhost/{POSTGRES_DB}"
)

# %% [markdown]
# ## Educational level

# %%
SQL = """select 
	"month", 
	educationlevel, -- Podemos cambiar el nivel de agrupamiento
	ROUND(avg(wage_amt)::numeric, 2) as avg_wage_amt, 
	ROUND(avg(food_amt)::numeric, 2) as avg_food_amt, 
	ROUND(avg(education_amt)::numeric, 2) as avg_education_amt, 
	ROUND(avg(shelter_amt)::numeric, 2) as avg_shelter_amt
from 
	vo_monthly_wage_cohorts vmwc 
group by 1,2
order by 1,4
"""

# %%
df = pd.read_sql(SQL, engine)

# %%
df.head(5)
# Out:
#      month       educationlevel  avg_wage_amt  avg_food_amt  \
# 0  2022-03             Graduate       9802.94       -376.68
# 1  2022-03            Bachelors       7902.45       -364.70
# 2  2022-03  HighSchoolOrCollege       4895.11       -301.01
# 3  2022-03                  Low       3963.30       -251.99
# 4  2022-04             Graduate       5796.96       -358.17
#
#    avg_education_amt  avg_shelter_amt
# 0             -26.25         -1434.50
# 1             -20.50         -1421.68
# 2             -30.76         -1000.56
# 3             -39.77          -757.84
# 4             -13.12          -687.83

# %%
df.dtypes
# Out:
# month                 object
# educationlevel        object
# avg_wage_amt         float64
# avg_food_amt         float64
# avg_education_amt    float64
# avg_shelter_amt      float64
# dtype: object

# %%
df.shape
# Out:
# (60, 6)

# %%
df.educationlevel.value_counts()
# Out:
# Graduate               15
# Bachelors              15
# HighSchoolOrCollege    15
# Low                    15
# Name: educationlevel, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
ax.set_title("Gasto en comida promedio por studies")
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_shelter_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
ax.set_title("Gasto de abrigo promedio por studies")
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
ax.set_title("Ingreso promedio por studies")
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Graduate"],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Bachelors"],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "HighSchoolOrCollege"],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_wage_amt",
    data=df[df.educationlevel == "Low"],
    marker="v",
    markerfacecolor="black",
    markersize=12,
    color="black",
    linewidth=4,
)
ax.set_title("Ingreso promedio por studies")
ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()

# %% [markdown]
# ## Plot avg from each participant

# %%
SQL = """select * from vo_monthly_wage_cohorts;"""

# %%
df = pd.read_sql(SQL, engine)

# %%
df.head(5)
# Out:
#      month  participantid  householdsize  age       educationlevel  \
# 0  2022-03              0              3   36  HighSchoolOrCollege
# 1  2022-03              1              3   25  HighSchoolOrCollege
# 2  2022-03              2              3   35  HighSchoolOrCollege
# 3  2022-03              3              3   21  HighSchoolOrCollege
# 4  2022-03              4              3   43            Bachelors
#
#   interestgroup  havekids  joviality  wage_amt  food_amt  ...  earning_amt  \
# 0             H      True   0.001627  11931.95   -268.34  ...     11931.95
# 1             B      True   0.328087  10359.02   -288.94  ...     10359.02
# 2             A      True   0.393470   9722.06   -290.48  ...      9722.06
# 3             I      True   0.138063   9407.86   -291.98  ...      9407.86
# 4             H      True   0.857397  11589.79   -300.05  ...     11589.79
#
#    spend_amt  balance_amt  wage_avg  food_avg  education_avg  shelter_avg  \
# 0   -1454.33     11014.30     83.44     -1.88          -0.53        -7.76
# 1   -1474.93      9461.98     58.86     -1.64          -0.43        -6.31
# 2   -1429.21      8873.82     64.81     -1.94          -0.17        -7.42
# 3   -1477.97      8513.85     64.44     -2.00          -0.52        -7.60
# 4   -7711.62      4478.26     55.45     -1.44          -0.12       -35.34
#
#    earning_avg  spend_avg  balance_avg
# 0        83.44     -10.17        77.02
# 1        58.86      -8.38        53.76
# 2        64.81      -9.53        59.16
# 3        64.44     -10.12        58.31
# 4        55.45     -36.90        21.43
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# month              object
# participantid       int64
# householdsize       int64
# age                 int64
# educationlevel     object
# interestgroup      object
# havekids             bool
# joviality         float64
# wage_amt          float64
# food_amt          float64
# education_amt     float64
# shelter_amt       float64
# earning_amt       float64
# spend_amt         float64
# balance_amt       float64
# wage_avg          float64
# food_avg          float64
# education_avg     float64
# shelter_avg       float64
# earning_avg       float64
# spend_avg         float64
# balance_avg       float64
# dtype: object

# %%
df.shape
# Out:
# (13331, 22)

# %%
# Big bins
plt.hist2d(
    df["food_amt"],
    np.array(df["wage_amt"], dtype=float),
    bins=(50, 50),
    cmap=plt.cm.jet,
)
plt.show()

# %%
# Big bins
plt.hist2d(
    df["participantid"],
    np.array(df["wage_amt"], dtype=float),
    bins=(50, 50),
    cmap=plt.cm.jet,
)
plt.show()

# %% [markdown]
# ## Other cohorts

# %%
SQL = """select 
	"month", 
	householdsize, 
	ROUND(avg(wage_amt)::numeric, 2) as avg_wage_amt, 
	ROUND(avg(food_amt)::numeric, 2) as avg_food_amt, 
	ROUND(avg(education_amt)::numeric, 2) as avg_education_amt, 
	ROUND(avg(shelter_amt)::numeric, 2) as avg_shelter_amt,
	ROUND(avg(earning_amt)::numeric, 2) as avg_earning_amt,
	ROUND(avg(spend_amt)::numeric, 2) as avg_spend_amt,
	ROUND(avg(balance_amt)::numeric, 2) as avg_balance_amt
from 
	vo_monthly_wage_cohorts vmwc 
group by 1,2
order by 1,4
"""

# %%
df = pd.read_sql(SQL, engine)

# %%
df.head(5)
# Out:
#      month  householdsize  avg_wage_amt  avg_food_amt  avg_education_amt  \
# 0  2022-03              1       6127.05       -363.41               0.00
# 1  2022-03              3       6664.32       -308.21             -95.37
# 2  2022-03              2       6251.86       -301.88               0.00
# 3  2022-04              2       4176.12       -346.91               0.00
# 4  2022-04              1       3246.87       -345.34               0.00
#
#    avg_shelter_amt  avg_earning_amt  avg_spend_amt  avg_balance_amt
# 0          -915.50          6127.05       -1278.91          5574.97
# 1         -1253.71          6664.32       -1657.29          5623.44
# 2         -1278.17          6251.86       -1580.05          5275.58
# 3          -791.31          4176.12       -1138.22          3731.72
# 4          -423.84          3246.87        -769.17          3168.38

# %%
df.dtypes
# Out:
# month                 object
# householdsize          int64
# avg_wage_amt         float64
# avg_food_amt         float64
# avg_education_amt    float64
# avg_shelter_amt      float64
# avg_earning_amt      float64
# avg_spend_amt        float64
# avg_balance_amt      float64
# dtype: object

# %%
df.shape
# Out:
# (45, 9)

# %%
# df.groupby(by=["householdsize", "month"]).count()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.householdsize == 1],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.householdsize == 2],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_food_amt",
    data=df[df.householdsize == 3],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
ax.set_title("Gasto promedio en comida por householdsize")
ax.legend(["1", "2", "3"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_earning_amt",
    data=df[df.householdsize == 1],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_earning_amt",
    data=df[df.householdsize == 2],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_earning_amt",
    data=df[df.householdsize == 3],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
ax.set_title("Ingreso promedio por householdsize")
ax.legend(["1", "2", "3"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
# figure(figsize=(20, 10), dpi=80)

# multiple line plots
ax.plot(
    "month",
    "avg_spend_amt",
    data=df[df.householdsize == 1],
    marker=".",
    markerfacecolor="blue",
    markersize=12,
    color="skyblue",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_spend_amt",
    data=df[df.householdsize == 2],
    marker="o",
    markerfacecolor="red",
    markersize=12,
    color="red",
    linewidth=4,
)
ax.plot(
    "month",
    "avg_spend_amt",
    data=df[df.householdsize == 3],
    marker="^",
    markerfacecolor="green",
    markersize=12,
    color="green",
    linewidth=4,
)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'month', 'avg_food_amt', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
ax.set_title("Gasto promedio por householdsize")
ax.legend(["1", "2", "3"])
plt.show()

# %% [markdown]
# ## Plot wages from each participant

# %%
SQL = """select * from financialjournal;"""

# %%
df = pd.read_sql(SQL, engine)

# %%
df.head(5)
# Out:
#    participantid             timestamp   category       amount
# 0              0  2022-03-01T00:00:00Z       Wage  2472.507559
# 1              0  2022-03-01T00:00:00Z    Shelter  -554.988622
# 2              0  2022-03-01T00:00:00Z  Education   -38.005380
# 3              1  2022-03-01T00:00:00Z       Wage  2046.562206
# 4              1  2022-03-01T00:00:00Z    Shelter  -554.988622

# %%
df.dtypes
# Out:
# participantid      int64
# timestamp         object
# category          object
# amount           float64
# dtype: object

# %%
df.shape
# Out:
# (1856330, 4)

# %%
df[df.category == "Wage"].shape
# Out:
# (508577, 4)

# %%
df[df.category == "Shelter"].shape
# Out:
# (14103, 4)

# %%
# # No da hay menos registros de cada uno
# # Big bins
# plt.hist2d(df[df.category == "Shelter"]["amount"], df[df.category == "Wage"]["amount"], bins=(50, 50), cmap=plt.cm.jet)
# plt.show()

# %%
# Big bins
figure(figsize=(13, 6), dpi=40)

plt.hist2d(
    df[df.category == "Wage"]["participantid"],
    df[df.category == "Wage"]["amount"],
    bins=(200, 200),
    cmap=plt.cm.jet,
)
plt.show()

# %% [markdown]
# # financial journal

# %%
SQL = """select * from vo_monthly_wage"""
df = pd.read_sql(SQL, engine)

# %%
df.spend_amt = -1 * df.spend_amt

# %%
fig, ax = plt.subplots(figsize=(12, 5))

for participant in df.participantid.tolist():
    ax.plot(
        "month",
        "earning_amt",
        data=df[df.participantid == participant],
        marker=".",
        markerfacecolor="green",
        markersize=1,
        color="lightgreen",
        alpha=0.1,
        linewidth=1,
    )
    ax.plot(
        "month",
        "spend_amt",
        data=df[df.participantid == participant],
        marker=".",
        markerfacecolor="red",
        markersize=1,
        color="red",
        alpha=0.1,
        linewidth=1,
    )
# ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [142], in <cell line: 3>()
#       1 fig, ax = plt.subplots(figsize=(12, 5))
# ----> 3 for participant in df.participantid.tolist():
#       4     ax.plot(
#       5         "month",
#       6         "earning_amt",
#    (...)
#      13         linewidth=1,
#      14     )
#      15     ax.plot(
#      16         "month",
#      17         "spend_amt",
#    (...)
#      24         linewidth=1,
#      25     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'participantid'

# %%
fig, ax = plt.subplots(figsize=(12, 5))

for participant in df.participantid.tolist():
    ax.plot(
        "month",
        "spend_amt",
        data=df[df.participantid == participant],
        marker=".",
        markerfacecolor="red",
        markersize=1,
        color="red",
        alpha=0.1,
        linewidth=1,
    )
# ax.legend(["Graduate", "Bachelors", "HighSchool", "Low"])
plt.show()
