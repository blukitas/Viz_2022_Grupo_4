# %% [markdown]
# # Daily wage evolution (as histogram)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sqlalchemy import create_engine

# %%
POSTGRES_USER = "viz_user"
POSTGRES_PASSWORD = "viz_pass"
POSTGRES_DB = "viz"

# %%
engine = create_engine(
    f"postgresql+psycopg2://{POSTGRES_USER}:{POSTGRES_PASSWORD}@localhost/{POSTGRES_DB}"
)

# %% [markdown]
# ## Lunes

# %%
SQL = """
  select vdw.* 
  	from vo_daily_wage_cohorts vdw
  	left join vo_date vd on vd.dt = vdw."month" 
  	where vd.dt_day_of_week = 1
"""
df = pd.read_sql(SQL, engine)

# %%
df.spend_amt = -1 * df.spend_amt

# %%
SQL = """
  select vdw.* 
  	from vo_daily_wage_cohorts vdw
  	left join vo_date vd on vd.dt = vdw."month" 
  	where vd.dt_day_of_week = 1
"""
df = pd.read_sql(SQL, engine)

# %%
df.spend_amt = -1 * df.spend_amt

# %%
df.head
# Out:
# <bound method NDFrame.head of             month  participantid  householdsize  age       educationlevel  \
# 0      2022-03-07              0              3   36  HighSchoolOrCollege
# 1      2022-03-07              1              3   25  HighSchoolOrCollege
# 2      2022-03-07              2              3   35  HighSchoolOrCollege
# 3      2022-03-07              3              3   21  HighSchoolOrCollege
# 4      2022-03-07              4              3   43            Bachelors
# ...           ...            ...            ...  ...                  ...
# 55435  2023-05-15           1006              1   19  HighSchoolOrCollege
# 55436  2023-05-15           1007              1   40  HighSchoolOrCollege
# 55437  2023-05-15           1008              1   23             Graduate
# 55438  2023-05-15           1009              1   39                  Low
# 55439  2023-05-15           1010              1   52  HighSchoolOrCollege
#
# ...

# %%
# figure(figsize=(30, 10), dpi=80)
# plt.figure(figsize=(30, 10))

fig, axs = plt.subplots(3, 3, figsize=(30, 15))

n, bins, patch = axs[0, 0].hist(
    df[df.month == "2022-03-07"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
axs[0, 0].set_title("Wage distribution - march first monday")

n, bins, patch = axs[0, 1].hist(
    df[df.month == "2022-04-04"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
axs[0, 1].set_title("Wage distribution - april first monday")

n, bins, patch = axs[0, 2].hist(
    df[df.month == "2022-05-02"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

n, bins, patch = axs[1, 0].hist(
    df[df.month == "2022-06-06"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[1, 1].hist(
    df[df.month == "2022-07-04"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[1, 2].hist(
    df[df.month == "2022-08-01"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

n, bins, patch = axs[2, 0].hist(
    df[df.month == "2022-09-05"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[2, 1].hist(
    df[df.month == "2022-10-03"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[2, 2].hist(
    df[df.month == "2022-11-07"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

# %% [markdown]
# ## Martes

# %%
SQL = """
  select vdw.* 
  	from vo_daily_wage_cohorts vdw
  	left join vo_date vd on vd.dt = vdw."month" 
  	where vd.dt_day_of_week = 2
"""
df = pd.read_sql(SQL, engine)

# %%
df.spend_amt = -1 * df.spend_amt

# %%
df.head(5)
# Out:
#         month  participantid  householdsize  age       educationlevel  \
# 0  2022-03-08              0              3   36  HighSchoolOrCollege
# 1  2022-03-08              1              3   25  HighSchoolOrCollege
# 2  2022-03-08              2              3   35  HighSchoolOrCollege
# 3  2022-03-08              3              3   21  HighSchoolOrCollege
# 4  2022-03-08              4              3   43            Bachelors
#
#   interestgroup  havekids  joviality  wage_amt  food_amt  ...  earning_amt  \
# 0             H      True   0.001627    411.28     -8.17  ...       411.28
# 1             B      True   0.328087    361.41     -8.70  ...       361.41
# 2             A      True   0.393470    316.75     -8.07  ...       316.75
# 3             I      True   0.138063    306.14     -9.11  ...       306.14
# 4             H      True   0.857397    396.91     -8.07  ...       396.91
#
#    spend_amt  balance_amt  wage_avg  food_avg  education_avg  shelter_avg  \
# ...

# %%
# figure(figsize=(30, 10), dpi=80)
# plt.figure(figsize=(30, 10))

fig, axs = plt.subplots(3, 3, figsize=(30, 15))

n, bins, patch = axs[0, 0].hist(
    df[df.month == "2022-03-08"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
axs[0, 0].set_title("Wage distribution - march first thursday")

n, bins, patch = axs[0, 1].hist(
    df[df.month == "2022-04-05"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
axs[0, 1].set_title("Wage distribution - april first thursday")

n, bins, patch = axs[0, 2].hist(
    df[df.month == "2022-05-03"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

n, bins, patch = axs[1, 0].hist(
    df[df.month == "2022-06-07"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[1, 1].hist(
    df[df.month == "2022-07-05"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[1, 2].hist(
    df[df.month == "2022-08-02"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

n, bins, patch = axs[2, 0].hist(
    df[df.month == "2022-09-06"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[2, 1].hist(
    df[df.month == "2022-10-04"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[2, 2].hist(
    df[df.month == "2022-11-08"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

# %% [markdown]
# ## 1 semana de abril

# %%
SQL = """
  select vdw.* 
  	from vo_daily_wage_cohorts vdw
  	left join vo_date vd on vd.dt = vdw."month" 
  	where vd.dt_month = 4
"""
df = pd.read_sql(SQL, engine)

# %%
df.spend_amt = -1 * df.spend_amt

# %%
df.head(5)
# Out:
#         month  participantid  householdsize  age       educationlevel  \
# 0  2022-04-03            845              2   40  HighSchoolOrCollege
# 1  2022-04-03            848              2   34             Graduate
# 2  2022-04-03            849              2   30            Bachelors
# 3  2022-04-03            850              2   57            Bachelors
# 4  2022-04-03            851              2   19             Graduate
#
#   interestgroup  havekids  joviality  wage_amt  food_amt  ...  earning_amt  \
# 0             G     False   0.234712      0.00     -9.11  ...         0.00
# 1             B     False   0.633520      0.00    -15.83  ...         0.00
# 2             I     False   0.828260      0.00     -8.47  ...         0.00
# 3             C     False   0.631432      0.00    -15.55  ...         0.00
# 4             D     False   0.677712    187.25    -13.59  ...       187.25
#
#    spend_amt  balance_amt  wage_avg  food_avg  education_avg  shelter_avg  \
# ...

# %%
# figure(figsize=(30, 10), dpi=80)
# plt.figure(figsize=(30, 10))

fig, axs = plt.subplots(3, 3, figsize=(30, 15))

n, bins, patch = axs[0, 0].hist(
    df[df.month == "2022-04-04"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
axs[0, 0].set_title("Wage distribution - march first thursday")

n, bins, patch = axs[0, 1].hist(
    df[df.month == "2022-04-05"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
axs[0, 1].set_title("Wage distribution - april first thursday")

n, bins, patch = axs[0, 2].hist(
    df[df.month == "2022-04-06"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

n, bins, patch = axs[1, 0].hist(
    df[df.month == "2022-04-07"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[1, 1].hist(
    df[df.month == "2022-04-08"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
n, bins, patch = axs[1, 2].hist(
    df[df.month == "2022-04-09"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)

n, bins, patch = axs[2, 0].hist(
    df[df.month == "2022-04-10"].wage_amt,
    bins=100,
    color="green",
    alpha=0.8,
    label="Value",
    edgecolor="orange",
    linewidth=2,
)
# n, bins, patch = axs[2,1].hist(
#     df[df.month == "2022-10-04"].wage_amt,
#     bins=100,
#     color="green",
#     alpha=0.8,
#     label="Value",
#     edgecolor="orange",
#     linewidth=2,
# )
# n, bins, patch = axs[2,2].hist(
#     df[df.month == "2022-11-08"].wage_amt,
#     bins=100,
#     color="green",
#     alpha=0.8,
#     label="Value",
#     edgecolor="orange",
#     linewidth=2,
# )
